# %% [markdown]
# # Employee details for exploratory data analysis

# %% [markdown]
# The dataset "employee working in ABC company" consist of 458 rows and 9 columns.In column comprises with 9 variables which shows employees Characterisitics and also essential for exploratory data analysis.The variables are: Name ,Team,Number,Position ,Age,Height,Weight,College,Salary.

# %% [markdown]
# #### Import necessary modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Load Data into Pandas DataFrame

# %%
data=pd.read_excel('myexcel.xlsx')
data
# Out:
#               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2     John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
# ..             ...             ...     ...      ...  ...                  ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454      Raul Neto       Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455   Tibor Pleiss       Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %%
data.head()
# Out:
#             Name            Team  Number Position  Age               Height  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1    Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2   John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3    R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
#
#    Weight            College     Salary
# 0     180              Texas  7730337.0
# 1     235          Marquette  6796117.0
# 2     205  Boston University        NaN
# 3     185      Georgia State  1148640.0
# 4     231                NaN  5000000.0

# %%
data.tail()
# Out:
#              Name       Team  Number Position  Age               Height  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454     Raul Neto  Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455  Tibor Pleiss  Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456   Jeff Withey  Utah Jazz      24        C   26                  7-0
# 457      Priyanka  Utah Jazz      34        C   25  2023-03-07 00:00:00
#
#      Weight College     Salary
# 453     203  Butler  2433333.0
# 454     179     NaN   900000.0
# 455     256     NaN  2900000.0
# 456     231  Kansas   947276.0
# 457     231  Kansas   947276.0

# %%
data.describe()
# Out:
#            Number         Age      Weight        Salary
# count  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  221.543668  4.833970e+06
# std     15.966837    4.400128   26.343200  5.226620e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
data.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
data.dtypes
# Out:
# Name         object
# Team         object
# Number        int64
# Position     object
# Age           int64
# Height       object
# Weight        int64
# College      object
# Salary      float64
# dtype: object

# %%
data.shape
# Out:
# (458, 9)

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 453    False
# 454    False
# 455    False
# 456    False
# 457    False
# Length: 458, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Handling Missing Values

# %%
data.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
data['Salary'] = data['Salary'].fillna(data['Salary'].mean())

# %%
avg_salary = data["Salary"].mean()
print(f"The average salary is: {avg_salary}")
# Out:
# The average salary is: 4833969.545861297

# %%
data.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary       0
# dtype: int64

# %%
data.fillna("unknown", inplace=True)

# %%
data.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %% [markdown]
# ## Preprocessing:
# <span style="color:blue"> Correct the data in the "height" column by replacing it with random numbers between 150 and 180. </span>

# %%
data['Height'] = np.random.uniform(150,180,size = len(data))

# %%
data
# Out:
#               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 6    Jordan Mickey  Boston Celtics      55       PF   21  2023-08-06 00:00:00
# 7     Kelly Olynyk  Boston Celtics      41        C   25                  7-0
# ..             ...             ...     ...      ...  ...                  ...
# 451  Chris Johnson       Utah Jazz      23       SF   26  2023-06-06 00:00:00
# 452     Trey Lyles       Utah Jazz      41       PF   20  2023-10-06 00:00:00
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %%
data
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  157.825594     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  171.513444     235
# 2     John Holland  Boston Celtics      30       SG   27  158.416768     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  150.720211     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  179.728452     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  152.278191     203
# 454      Raul Neto       Utah Jazz      25       PG   24  167.891017     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  162.409593     256
# 456    Jeff Withey       Utah Jazz      24        C   26  157.219124     231
# 457       Priyanka       Utah Jazz      34        C   25  167.969622     231
#
#                College        Salary
# ...

# %% [markdown]
# # Analysis Tasks:

# %% [markdown]
# ### <span style="color:blue">1.Determine the distribution of employees across each team and calculate the percentage split relative to the total number of employees.</span>

# %%
data['Team'].value_counts()
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %% [markdown]
# ### <span style="color:blue">calculate the percentage split relative to the total number of employees.</span>

# %%
data['Team'].value_counts()/len(data)*100
# Out:
# Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# Toronto Raptors           3.275109
# ...

# %%
#Count Plot
plt.figure(figsize=(25,6))
plt.xticks(rotation=45)
sns.countplot(x ='Team',data = data,hue = 'Team',palette = 'flare')
# Out:
# <Axes: xlabel='Team', ylabel='count'>

# %%
no_team=30
no_employee  =458

# %%
team = pd.Series(data["Team"].value_counts())
percentage =(team/no_employee)*100
result = pd.concat([team,percentage.round(2)],axis=1,keys = ["no of employee","percentage"])
result
# Out:
#                         no of employee  percentage
# Team
# New Orleans Pelicans                19        4.15
# Memphis Grizzlies                   18        3.93
# Utah Jazz                           16        3.49
# New York Knicks                     16        3.49
# Milwaukee Bucks                     16        3.49
# Brooklyn Nets                       15        3.28
# Portland Trail Blazers              15        3.28
# Oklahoma City Thunder               15        3.28
# Denver Nuggets                      15        3.28
# Washington Wizards                  15        3.28
# Miami Heat                          15        3.28
# Charlotte Hornets                   15        3.28
# Atlanta Hawks                       15        3.28
# San Antonio Spurs                   15        3.28
# Houston Rockets                     15        3.28
# Boston Celtics                      15        3.28
# Indiana Pacers                      15        3.28
# ...

# %% [markdown]
# ## Insight

# %% [markdown]
# ### <span style="color:red">The countplot shows the distribution of employees across different teams in the organization.New Orleans Pelicans has the highest count as 19 followed by Memphis Grizzlies as 18 among all teams.</span>

# %% [markdown]
# ### <span style="color:blue"> 2.Segregate employees based on their positions within the company.</span>

# %%
data["Position"].value_counts()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
grouped_by_position = data.groupby("Position")
for position, group in grouped_by_position:
    print(f"position:{position}")
    print(group[["Name","Position"]])
    print("\n")
# Out:
# position:C
#                 Name Position
# 7       Kelly Olynyk        C
# 10   Jared Sullinger        C
# 14      Tyler Zeller        C
# 23       Brook Lopez        C
# 27        Henry Sims        C
# ..               ...      ...
# 439    Mason Plumlee        C
# 447      Rudy Gobert        C
# 455     Tibor Pleiss        C
# 456      Jeff Withey        C
# 457         Priyanka        C
#
# [79 rows x 2 columns]
#
#
# position:PF
#                  Name Position
# 4       Jonas Jerebko       PF
# 5        Amir Johnson       PF
# 6       Jordan Mickey       PF
# 24   Chris McCullough       PF
# 25        Willie Reed       PF
# ..                ...      ...
# 435    Meyers Leonard       PF
# 441       Noah Vonleh       PF
# 442     Trevor Booker       PF
# 446    Derrick Favors       PF
# 452        Trey Lyles       PF
#
# [100 rows x 2 columns]
#
#
# position:PG
#               Name Position
# 0    Avery Bradley       PG
# 8     Terry Rozier       PG
# ...

# %%
position_counts = data['Position'].value_counts()

#  bar chart
plt.figure(figsize=(8, 5))
position_counts.plot(kind='bar', color='skyblue')
plt.title('Number of Players by Position')
plt.xlabel('Position')
plt.ylabel('Count of Players')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# #### <span style="color:red"> The Shooting Guard (SG) position has the highest representation in the bar chart, with 102 players.Followed by PF ,PG,SF,C.</span>

# %% [markdown]
# ### <span style="color:blue"> 3. Identify the predominant age group among employees.</span>

# %%
data['Age Group'] = data['Age'].apply(lambda age:'20-25' if 20 <= age <= 25 else ('26-30' if 26 <= age <= 30 else ('31-35' if 31 <= age <= 35 else '36 -40')))
data
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  157.825594     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  171.513444     235
# 2     John Holland  Boston Celtics      30       SG   27  158.416768     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  150.720211     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  179.728452     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  152.278191     203
# 454      Raul Neto       Utah Jazz      25       PG   24  167.891017     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  162.409593     256
# 456    Jeff Withey       Utah Jazz      24        C   26  157.219124     231
# 457       Priyanka       Utah Jazz      34        C   25  167.969622     231
#
# ...

# %%
data["Age Group"].value_counts()
# Out:
# Age Group
# 20-25     198
# 26-30     167
# 31-35      68
# 36 -40     25
# Name: count, dtype: int64

# %%
age_group_counts = data['Age Group'].value_counts()
# pie chart
plt.figure(figsize=(6, 6))
plt.pie(age_group_counts.values, labels=age_group_counts.index, autopct='%1.1f%%', colors=['#FF9999', '#66B3FF', '#99FF99', '#FFCC99'])
plt.title('Proportion of Employees by Age Group')
plt.show()

# %% [markdown]
# #### <span style="color:red">A pie chart showing the percentage of employees in each age group based on the counts provided.The 20-25 age group dominates, accounting for the largest proportion of employees with 43.2 %.26-30 age group follows as the second-largest with36.5%.

# %% [markdown]
# ### <span style="color:blue">4.Discover which team and position have the highest salary expenditure.</span>

# %%
data["Salary"].value_counts()
# Out:
# Salary
# 9.472760e+05    32
# 8.450590e+05    18
# 5.250930e+05    13
# 4.833970e+06    11
# 9.813480e+05     6
#                 ..
# 2.100000e+06     1
# 1.252440e+06     1
# 2.891760e+06     1
# 3.272091e+06     1
# 9.000000e+05     1
# Name: count, Length: 310, dtype: int64

# %%
df1 = data[["Name","Team","Position","Salary"]]
df1
# Out:
#               Name            Team Position        Salary
# 0    Avery Bradley  Boston Celtics       PG  7.730337e+06
# 1      Jae Crowder  Boston Celtics       SF  6.796117e+06
# 2     John Holland  Boston Celtics       SG  4.833970e+06
# 3      R.J. Hunter  Boston Celtics       SG  1.148640e+06
# 4    Jonas Jerebko  Boston Celtics       PF  5.000000e+06
# ..             ...             ...      ...           ...
# 453   Shelvin Mack       Utah Jazz       PG  2.433333e+06
# 454      Raul Neto       Utah Jazz       PG  9.000000e+05
# 455   Tibor Pleiss       Utah Jazz        C  2.900000e+06
# 456    Jeff Withey       Utah Jazz        C  9.472760e+05
# 457       Priyanka       Utah Jazz        C  9.472760e+05
#
# [458 rows x 4 columns]

# %%
total_salary = df1.groupby(["Team","Position"])["Salary"].sum()
max_spending = total_salary.idxmax()
max_spending_salary = total_salary.max()
print(f"The team and position with the highest spending is:\n Team: {max_spending[0]}\n position: {max_spending[1]} \n with a total salary of {max_spending_salary}.")
# Out:
# The team and position with the highest spending is:
#  Team: Los Angeles Lakers
#  position: SF
#  with a total salary of 31866445.0.

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=grouped, x="Salary", y="Team", hue="Position", dodge=False, palette="pastel")
plt.title("Salary Spending by Team and Position")
plt.xlabel("Salary Expenditure")
plt.ylabel("Team")
plt.show()

# %% [markdown]
# #### <span style="color:red">The Los Angeles Lakers allocate the highest salary to the Small Forward position compared to all other teams and positions. This significant expenditure highlights the strategic importance of this role within their lineup.Followed by Miami Heat to the PF Position.</span>

# %% [markdown]
# ### <span style="color:blue">5.Investigate if there's any correlation between age and salary, and represent it visually.</span>

# %%
df2 = data[["Age","Salary"]]
df2
# Out:
#      Age        Salary
# 0     25  7.730337e+06
# 1     25  6.796117e+06
# 2     27  4.833970e+06
# 3     22  1.148640e+06
# 4     29  5.000000e+06
# ..   ...           ...
# 453   26  2.433333e+06
# 454   24  9.000000e+05
# 455   26  2.900000e+06
# 456   26  9.472760e+05
# 457   25  9.472760e+05
#
# [458 rows x 2 columns]

# %%
correlation = data["Age"].corr(data["Salary"])
print(f"Correlation between Age and Salary: {correlation:.2f}")
# Out:
# Correlation between Age and Salary: 0.21

# %%
#Scatter Plot Showing Correlation
sns.scatterplot(x="Age" ,y= "Salary",data= data)
plt.ylabel("Salary")
plt.xlabel("Age")
plt.title("correlation b/w Salary and Age")
plt.show()

# %% [markdown]
# #### <span style="color:red">As the Scatter Plot shows there is  strong positive correlation between age and salary suggests that, in this dataset, as employees grow older, they tend to earn higher salaries. However, while age is a significant factor, other variables should also be considered when analyzing salary trends in a real-world context.</span>

# %% [markdown]
# ### Conclusion

# %% [markdown]
# ### The Python-based exploratory data analysis (EDA) of ABC Company’s employee and team data highlights significant trends in salary distribution, particularly in relation to age and position. While older employees generally earn more, there are notable outliers and a need to consider multiple factors when determining salary progression.The analysis demonstrated the ability to visualize and analyze complicated datasets using Python tools such as Matplotlib, Seaborn, and Pandas.
